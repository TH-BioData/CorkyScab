# %% [markdown]
# # CorkyScab – Demo
#
# This notebook shows a workflow using the **CorkyScab** package:
# 1. Load potato images with corky scab.
# 2. Import the CorkyScab package.
# 3. Call the `analyze_corky_scab` function.
# 4. Save the generated table and figures.
#
#
# ---
#
#
# # CorkyScab – Demo
#
# Este notebook muestra un flujo de trabajo usando el paquete **CorkyScab**:
# 1. Cargar imágenes de papas con corchosis.
# 2. Importar el paquete CorkyScab
# 3. Llamar a la función `analyze_corky_scab`
# 4. Guardar la tabla y figuras generadas.

# %%
# If we are in Google Colab, mount Google Drive and install the package.
from google.colab import drive
drive.mount('/content/drive')

# !pip install /content/drive/MyDrive/CorkyScab_package/corky_scab.zip # Modify the path if necessary. It is NOT necessary to unzip the file.

import corky_scab as cksc
import pandas as pd
# Out:
# Mounted at /content/drive
# Processing ./drive/MyDrive/CorkyScab_package/corky_scab.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for corky-scab: filename=corky_scab-0.1.0-py3-none-any.whl size=7039 sha256=068120fac702e9cb3ffca4c4c1cb7574cf33e0bb483a6f4bf17519cbf64ccff1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-823q0_d4/wheels/da/9a/1f/47da797cac464f3e72c46220dbf7b1f78bc4a1c010823fd0f8
# Successfully built corky-scab
# ...

# %%
# Image processing
# Modify with the name of our image.

perc, mask, fig = cksc.analyze_corky_scab('/content/drive/MyDrive/Corchosis/fotos/3.0.png', return_fig=True)
print("Lesion %:", perc)
# Out:
# 🔍 Starting corky scab analysis with aggressive smoothing...
# 🔧 Image resized for processing: 541x600
# ✅ Image loaded and potato segmented: (541, 600, 3)
# ✅ Potato area: 183915 pixels
# ✅ K-Means segmentation completed
# ✅ Cluster identification completed
# 🔧 Applying aggressive false-positive cleanup...
# ✅ Aggressive post-processing completed
# ✅ ANALYSIS COMPLETED
# 📊 Corky scab percentage: 7.34%
# Lesion %: 7.337628795911155

# %%
# Save figures
cksc.save_figures(fig, out_dir="/content/outputs", base_name="3_0_analysis")
# Out:
# 🖼️ Figures saved to:
#  - /content/outputs/3_0_analysis.png
#  - /content/outputs/3_0_analysis.pdf
# ('/content/outputs/3_0_analysis.png', '/content/outputs/3_0_analysis.pdf')

# %%
# Save percentage as a csv
df = cksc.analyze_corky_scab_to_df('/content/drive/MyDrive/Corchosis/fotos/3.0.png')
cksc.save_results_df(df, "/content/outputs/results.csv")
df
# Out:
# 🔍 Starting corky scab analysis with aggressive smoothing...
# 🔧 Image resized for processing: 541x600
# ✅ Image loaded and potato segmented: (541, 600, 3)
# ✅ Potato area: 183915 pixels
# ✅ K-Means segmentation completed
# ✅ Cluster identification completed
# 🔧 Applying aggressive false-positive cleanup...
# ✅ Aggressive post-processing completed
# ✅ ANALYSIS COMPLETED
# 📊 Corky scab percentage: 7.34%
# 🧾 Results saved to: /content/outputs/results.csv
#   image_name  lesion_percentage
# 0    3.0.png           7.337629
